# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# hw7.2
from sympy import *

m = 7.0
g = 9.8
v0 = 11.0
vf = 24.0
########################

h=(vf**2-v0**2)/m/g
print(h)
# Out:
# 6.632653061224489

# %%
# hw7.3
