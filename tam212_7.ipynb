# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# hw7.2
from sympy import *

m = 7.0
g = 9.8
v0 = 11.0
vf = 24.0
########################

h=(vf**2-v0**2)/m/g
print(h)
# Out:
# 6.632653061224489

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 7.3
from sympy import *

m1 = 8.0
m2 = 2.0
rOP = Matrix([-2,  3,  0])
rPQ = Matrix([1, 0, 0])
g = 9.8



E1=m1*g*(rOP[1]/2)
E2=m2*g*(rOP[1]+rPQ[1]/2)


print(E1+E2)
# Out:
# 176.400000000000

# %%
#HW13_3:
from sympy import *

m1 = 5.0
m2 = 4.0
rOP = Matrix([1, 2, 0])
rPQ = Matrix([1, 1, 0])
g = 9.8

Ep1 = m1*g*(rOP[1]/2)
Ep2 = m2*g*(rOP[1]+rPQ[1]/2)
print(Ep1+Ep2)
# Out:
# 147.000000000000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *

m = 9.0
r = 3.0
g = 9.8
h = 16.0
v0 = 6.0

vf=S('vf')
I=m*r**2


w0=v0/r
E0=1/2*m*v0**2+1/2*I*w0**2+m*g*h

w1=vf/r
E1=1/2*m*vf**2+1/2*I*w1**2+m*g*r


solve(E0-E1)
# Out:
# [-12.7828009450198, 12.7828009450198]

# %%
#HW13_4:
from sympy import *

m = 9.0
r = 3.0
g = 9.8
h = 16.0
v0 = 6.0


######

I = m*r**2
Et = (m*v0**2/2) + (I*(v0/r)**2/2) + m*g*h

vf = symbols("vf")
eq = (m*vf**2/2) + (I*(vf/r)**2/2) + m*g*r - Et
ans = solve(eq,vf)
print(ans)

#################################
from sympy import *

m = 2.0
r = 5.0
g = 9.8
h = 13.0
vf = 23.0

######

I = m*r**2
Et = (m*vf**2/2) + (I*(vf/r)**2/2) + m*g*r
v0 = symbols("v0")
eq = (m*v0**2/2) + (I*(v0/r)**2/2) + m*g*h - Et
ans = solve(eq,v0)
print(ans)
# Out:
# [-12.7828009450198, 12.7828009450198]
# [-21.2273408603150, 21.2273408603150]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#HW13_5:
from sympy import *

m = 4.0
v0 = 3.0
h = 15.0
g = 9.8
vf = 8.0
######################


Wf = m*(vf**2/2 - v0**2/2 - g*h)
print(Wf)
# Out:
# -478.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#HW13_6:
from sympy import *

m = 8
theta = 45 # in degrees
k = 150
h = 3
##########################

theta = theta/180*pi
deltx = symbols('deltx')
deltE = m*g*(h+deltx*sin(theta))

eq = k*deltx**2/2 - deltE
ans = solve(eq,deltx)
print(ans)
# Out:
# [-1.43944904401130, 2.17861133261164]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 7.7

from sympy import *

m = 7
F = Matrix([1, 9, 0])
t0 = 0
r0 = Matrix([-7, -5,  0])
tf = 3
rf = Matrix([ 6, -2,  0])
################################
dertar=rf-r0
w=F.dot(dertar)
print(w)
# Out:
# 40

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#HW13_8:
from sympy import *

m1 = 7
m2 = 3
rOP = Matrix([2, 1, 0])
rPQ = Matrix([1, 1, 0])
omega1 = Matrix([ 0,  0, -1])
omega2 = Matrix([0, 0, 1])


I1=1/3*m1*rOP.norm()**2
I2=1/3*m2*rOP.norm()**2

vP=omega1.cross(rOP)

vP = omega1.cross(rOP)


Ek1 = (I1*omega1.norm()**2/2) #+ (m1*(omega1.cross(rOP)/2).norm()**2/2)


Ek2 = (I2*omega2.norm()**2/2) + (m2/2*(vP.norm())**2+m2*vP.dot(omega2.cross(rPQ)/2))


T=Ek1+Ek2
print(T)
# Out:
# 9.83333333333333

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#HW13_9:
from sympy import *

m = 6.00
k = 163.00
dx1 = 1.00
dx2 = 0

Ep = k*(dx1**2-dx2**2)/2
v = (Ep*2/m)**0.5


print('注意符号，这里只是数值：',v)

#################################
from sympy import *

m = 9.00
k = 150.00
dx1 = 0.50
dx2 = 0.14


a = k*dx2/m
print("注意符号，这里只是数值：",a)
# Out:
# 注意符号，这里只是数值： 5.212165257037297
# 注意符号，这里只是数值： 2.333333333333334

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#HW13_10:
from sympy import *

m = 3.000
mu = 0.875
g = 9.800

ang = atan(mu)
print((ang/pi*180).evalf())
# Out:
# 41.1859251657096

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *

m = 7.000
thetaDeg = 35.000 # in degrees
mu = 0.750
g = 9.800

if (mu - tan(thetaDeg/180*pi)) > 0:
    print('stick')
else:
    print("slip and acc")
# Out:
# stick

# %%
import numpy as np
from sympy import *

m = 4
r = 4
D = Matrix([-11,-14, 0])
g = Matrix([0, -9.8, 0])
mu = 1

# %%
#7.12
import numpy as np
from sympy import *

m = 3
r = 4
D = Matrix([5,27, 0])
g = Matrix([0, -9.8, 0])
mu = 1.25


rCP = Matrix([-r,0,0]) #手动改
rCQ = Matrix([0,-r,0])
FQ = (D + m*g)[1]
fm = Abs(FQ)*mu

Iz = 0.5*m*r**2
x,y,z = symbols('x,y,z')



f = Matrix([x,0,0])



M = rCQ.cross(f) + rCP.cross(D)
alpha = M/Iz
aC = alpha.cross(-rCQ)

eq1 = (D+f)[0]/m - aC[0]


f = Matrix([solve(eq1)[0],0,0])



if Abs(solve(eq1)[0]) <= fm:
    print('无滑动滚动')
    aC = Matrix([(D+f)[0]/m,0,0])
    display(aC)
    M = rCQ.cross(f) + rCP.cross(D)
    alpha = M/Iz
    aCP = alpha.cross(rCP)
    aP = aC + aCP
    display(aP)
    display(alpha)


else:
    print('滑动')
    if rCP.cross(D)[2] >= 0:
        f = Matrix([-fm,0,0])
    else:
        f = Matrix([fm,0,0])


    aC = Matrix([(D+f)[0]/m,0,0])

    display(aC)
    M = rCQ.cross(f) + rCP.cross(D)
    alpha = M/Iz


    aCP = alpha.cross(rCP)
    aP = aC + aCP
    display(aP)
    display(alpha)
# Out:
# 滑动
# Matrix([
# [2.66666666666667],
# [               0],
# [               0]])
# Matrix([
# [2.66666666666667],
# [            16.0],
# [               0]])
# Matrix([
# [   0],
# [   0],
# [-4.0]])

# %%
# 

import numpy as np
from sympy import *

m = 3
r = 4
D = Matrix([5,27, 0])
g = Matrix([0, -9.8, 0])
mu = 1.25

rCP=Matrix([-r,0,0])
rQC=Matrix([0,r,0])
rCQ=Matrix([0,-r,0])

F=D+m*g
fm=abs(F[1]*mu)

x=S('x')
f=Matrix([x,0,0])


M=rCP.cross(D)+rCQ.cross(f)
Iz=1/2*m*r**2
alpha=M/Iz


ac=alpha.cross(rQC)
q1=(D+f)[0]/m-ac[0]

x=solve(q1)[0]

f=Matrix([x,0,0])


print(f)
print(fm)




# ac=Matrix([(D+f)/m,0,0])
# print((D+f)/m)
# print(ac)




if abs(f)>abs(fm):
    print('滑动')
    if rCP.cross(D)[2] >= 0:
        f = Matrix([-fm,0,0])
    else:
        f = Matrix([fm,0,0])
    ac=Matrix()



print('滑动')

if rCP.cross(D)[2] >= 0:
    f = Matrix([-fm,0,0])
else:
    f = Matrix([fm,0,0])


aC = Matrix([(D+f)[0]/m,0,0])

display(aC)
M = rCQ.cross(f) + rCP.cross(D)
alpha = M/Iz


aCP = alpha.cross(rCP)
aP = aC + aCP
display(aP)
display(alpha)
# Out:
# Matrix([[16.3333333333333], [0], [0]])
# 3.00000000000000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 49
#      37 print(fm)
#      42 # ac=Matrix([(D+f)/m,0,0])
#      43 # print((D+f)/m)
#      44 # print(ac)
# ---> 49 if abs(f)>abs(fm):
#      50     print('滑动')
#      51     if rCP.cross(D)[2] >= 0:
#
# TypeError: '>' not supported between instances of 'MutableDenseMatrix' and 'Float'
