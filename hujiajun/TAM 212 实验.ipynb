# %%
from math import *
import numpy as np
import sympy as sy

mm=0.001
cm=0.01

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#参数
g=9.79      #本地重力加速度
m=2.7*0.001 #乒乓球质量 kg
d=40*mm     #乒乓球直径 m

def c(t,h):
    g=9.79    
    m=2.7*0.001 
    c=sy.S('c')
    equ=(g*m*(m*-e**(c*t/m)+c*t+m))+c**2*h
    
    ans=sy.solve([equ],[c])
    return ans


c(623/960,2)
