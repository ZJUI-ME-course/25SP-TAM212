# %%
from math import *
import numpy as np
import sympy as sy
from numpy import cross

# %% [markdown]
# 知识重点
# ---
# 1. $a_{和}=a_{径向}+a_{切向}=\omega^2 \cdot r + \alpha \cdot r$
# 2. $\omega_1 \cdot r_1=-\omega_2 \cdot r_2$ (对于齿轮)
# 3. $\alpha_1 \cdot r_1=-\alpha_2 \cdot r_2$ (上面式子对时间 $t$ 的求导)
#
# 题目列表
# ---
# (都比较简单)
# 1. (🔠选择题) 463 加速度比大小
# 2. (📐计算题) 1038 角速度传递 (简单)
# 3. (🟨画图题) 350 质心
# 4. (📐计算题) 1022 传递 (其实比较简单。但参数会变来变去)
# 5. (🔠选择题) 173 速度比大小
# 6. (📐计算题) 140 计算转动惯量 (其实比较简单。但参数会变来变去)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #a=v^2/r  #❓❓❓❓❓❓

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
r4=1
############复制部分
r1 = 9
r2 = 6
r3 = 5
omega1 = -8
############

omega3=omega1*(-r1/r2)*(-r2/r3)
#omega1=omega4*(-r4/r3)*(-r3/r2)*(-r2/r1)
#omega4=omega1*(-r1/r2)*(-r2/r3)*(-r3/r4)

omega1,omega3,omega4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0b3f295fbce4> in <module>
#      11 #omega4=omega1*(-r1/r2)*(-r2/r3)*(-r3/r4)
#      12
# ---> 13 omega1,omega3,omega4
#
# NameError: name 'omega4' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#此程序由omega→答案
omega1Mag=0;omega2Mag=0;omega3Mag=0;omega4Mag=0
###################复制部分
r1 = 5
r2 = 9
r3 = 7
r4 = 7
aP = 73
omega4Mag = 3
###################
if omega1Mag!=0:
    v=omega1Mag*r1
if omega2Mag!=0:
    v=omega2Mag*r2
if omega3Mag!=0:
    v=omega3Mag*r3
if omega4Mag!=0:
    v=omega4Mag*r4

key1=input('输入P的位置(例如1)')
key2=input('输入目标的位置(例如1)')
direction1=(int(input('顺时针=1，逆时针=2'))-1.5)*2
key4=input('输入谁有旋转方向')
delta=abs(int(key4)-int(key2))
direction2=(-1)**delta #与已知旋转方向的差几个圆的距离

#新函数⭐⭐⭐
#locals()['你要的变量名']
#该函数会返回该变量的值
r=locals()['r'+key1]
R=locals()['r'+key2]
an=v**2/r
at=sqrt(aP**2-an**2)
alpha=at/r

alpha_ans=alpha*r/R*direction2*direction1
omega_ans=v/R*direction2*direction1

print('alpha=',alpha_ans,'omega=',omega_ans)
# Out:
# 输入P的位置(例如1)3
# 输入目标的位置(例如1)1
# 顺时针=1，逆时针=21
# 输入谁有旋转方向2
# alpha= 7.37563556583431 omega= 4.2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 我的评价是：这道题没什么难度，只要注意比较的是Magnitude，不带正负号

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
r=int(input('r='))
m1=int(input('m1='))

L=int(input('L='))
m2=int(input('m2='))

l1=int(input('l1='))
l2=int(input('l2='))
m3=int(input('m3='))

m4=int(input('m4='))
# Out:
# r=1
# m1=2
# L=5
# m2=2
# l1=3
# l2=4
# m3=3
# m4=3

# %%
from sympy import integrate

r=1
m1=2
L=5
m2=2
l1=3
l2=4
m3=3
m4=3

D1=r
D2=(r**2+(0.5*L-r)**2)**0.5
D3=((0.5*l2-r)**2+(0.5*l1+L-r)**2)**0.5

#计算盘的转动惯量
I1=0.5*m1*r**2+m1*D1**2
       
#计算棍的转动惯量
I2=1/12*m2*L**2+m2*D2**2
       
#计算方的转动惯量
I3=1/12*m3*(l1**2+l2**2)+m3*D3**2

I=I1+I2+I3
# Out:
# 113.66666666666669
