# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from math import *
import numpy as np
import sympy as sy

# %%
fc=0.5
wc=2*pi*fc

rw=0.3 #m

vmax=rw*wc*(0.0848/0.0222)*3600/1000
vmin=rw*wc*(0.0485/0.0647)*3600/1000

print(vmax,vmin)
# Out:
# 12.960343314701245 2.543379029289542

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
(2*(1+0.95)/(1+2*0.95))
rs=0.034
rw=0.3
rc=0.085
wc=3.14

g1=0.743589
g3=1.344827

ws=rc*wc/rs

v1=rw*g1*ws
v3=rw*g3*ws

print(v1,v3)
# Out:
# 1.7511520950000004 3.167067585

# %%
G2=2.356
